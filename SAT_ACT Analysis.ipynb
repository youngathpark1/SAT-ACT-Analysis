# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# In this analysis, I set out to answer the question **"Is there a meaningful relationship between standarized test performance and family financial background?"**
#
# While standarized tests like SAT and ACT strive to enable colleges to objectively evaluate their applicants' competency in areas such as math, reading, and writing, which are critical skills required for success in higher education, it is important to note that these standarized test scores should and need to be viewed and weighted through proper social and cultural perspectives.
#
# One of the considerations is the intricate and complex relationship that may exist between test scores and contextual factors such as family background, ethnicity, race, and etc. For instance, intuitively speaking, it isn't a big of a stretch to infer that students who come from wealthier backgrounds may perform better on standarized tests than students that come from families with low income. As you can imagine, it is probably more likely for students that come from wealthier backgrounds to have access to better education system support and resources that students who come from poorer background may not have the luxury of leveraging for their academic success.
#
# In order to answer this question, I examined the historical SAT and ACT test results from 2017 and 2019 and compared the results against median household income based on 3-yr average data provided by the [United States Census Bureau(Table H-8B).](https://www.census.gov/data/tables/time-series/demo/income-poverty/historical-income-households.html)

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Data-Visualization)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Data Sources:

# %% [markdown]
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`2017-19 US Household Median Income by State`](./data/2017_2019_us_family_median_income_3yr_avg.csv): [US Household Median Income by State](https://www.census.gov/data/tables/time-series/demo/income-poverty/historical-income-households.html)

# %% [markdown]
# ### Outside Research

# %% [markdown]
# During my initial reserach, I came across many opinions, articles, and blogs with various degrees of claims, conclusions, and inferences. It was a bit surprising to see such a wide range of thoughts on this topic. I found these two articles to be the most informative and thought-provoking. I also think they are good representatives of the two very opposing views on this topic which make them even more interesting when read in comparsion to each other.
#
# 1). [Why Elites Dislike Standarized Testing](https://quillette.com/2019/03/13/standardized-testing-and-meritocracy/)
#
# 2). [Race gaps in SAT scores highlight inequality and hinder upward mobility](https://www.brookings.edu/research/race-gaps-in-sat-scores-highlight-inequality-and-hinder-upward-mobility/)
#
# In the first article, author Daniel Friedman sees standarized tests like SAT and ACT as means to protect and preserve meritocracy. He challenges the idea that standarized tests like SAT and ACT at a scale are designed to reward socioeconomic status and parental resources.
#
# "*But while it’s true that higher-income students get better scores on average and lower-income students do worse, it doesn’t necessarily follow that money raises test scores. This is a mere correlation, and, as anyone who did well on the SAT knows, correlation doesn’t imply causation*."
#
# The second article takes it a step further and brings in the racial inequality into the equation and argues that standarized tests like SAT and ACT are embedded with biases to favor the wealthy and hinder upward mobility for miniorities.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def calc_mean(values):
    return sum(values)/len(values)

# %%
# Example

calc_mean([1,2,3])
# Out:
# 2.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def calc_std(values):
    mean_values = calc_mean(values)
    sum_values = 0
    
    for num in values:
        sum_values += (num - mean_values) ** 2
        
    return (sum_values/len(values)) ** 0.5

# %%
# Example

calc_std([1,2,3])
# Out:
# 0.816496580927726

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

def data_clean_func(s):
    s_new=[]
    for i in s:
        s_new.append(float(i.replace("%",""))/100)
    return s_new

# %%
data_clean_func(['30.5%', '30.2%'])
# Out:
# [0.305, 0.302]

# %% [markdown]
# ## Data Import and Cleaning

# %%
# Libary imports:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading data into pandas

sat_17 = pd.read_csv('../data/sat_2017.csv')
sat_18 = pd.read_csv('../data/sat_2018.csv')
sat_19 = pd.read_csv('../data/sat_2019.csv')
act_17 = pd.read_csv('../data/act_2017.csv')
act_18 = pd.read_csv('../data/act_2018.csv')
act_19 = pd.read_csv('../data/act_2019.csv')
us_income = pd.read_csv('../data/2017_2019_us_family_median_income_3yr_avg.csv')

# %% [markdown]
# ***In the steps below, I go through each dataframe and check for nulls, modify dtypes as needed, and filter out information not relevant to this analysis***

# %%
sat_17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_17.tail()
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           65%                                 561   541
# 47     Washington           64%                                 541   534
# 48  West Virginia           14%                                 558   528
# 49      Wisconsin            3%                                 642   649
# 50        Wyoming            3%                                 626   604
#
#     Total
# 46   1102
# 47   1075
# 48   1086
# 49   1291
# 50   1230

# %%
sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_17[sat_17['State']=='Maryland']
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# Replacing the Math SAT mean score to 524

sat_17.loc[sat_17['State'] == 'Maryland','Math'] = 524

sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  556.882353  1126.098039
# std                             45.666901   47.121395    92.494812
# min                            482.000000  468.000000   950.000000
# 25%                            533.500000  523.500000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# Applying the data_clean_func I wrote above to Participation column (drops % and converts to decimal)

sat_17['Participation'] = data_clean_func(list(sat_17['Participation']))

# %%
# Rename the column Evidence-Based Reading and Writing to EBRW and apply lower()

sat_17.rename(columns = {'Evidence-Based Reading and Writing':'EBRW'}, inplace=True)
sat_17.columns = sat_17.columns.str.lower()
sat_17.head()
# Out:
#         state  participation  ebrw  math  total
# 0     Alabama           0.05   593   572   1165
# 1      Alaska           0.38   547   533   1080
# 2     Arizona           0.30   563   553   1116
# 3    Arkansas           0.03   614   594   1208
# 4  California           0.53   531   524   1055

# %%
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   ebrw           51 non-null     int64
#  3   math           51 non-null     int64
#  4   total          51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_18.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
sat_18['Participation'] = data_clean_func(list(sat_18['Participation']))

sat_18.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
sat_18.rename(columns = {'Evidence-Based Reading and Writing':'EBRW'}, inplace=True)
sat_18.columns = sat_18.columns.str.lower()

sat_18.head()
# Out:
#         state  participation  ebrw  math  total
# 0     Alabama           0.06   595   571   1166
# 1      Alaska           0.43   562   544   1106
# 2     Arizona           0.29   577   572   1149
# 3    Arkansas           0.05   592   576   1169
# 4  California           0.60   540   536   1076

# %%
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   ebrw           51 non-null     int64
#  3   math           51 non-null     int64
#  4   total          51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_19.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %% [markdown]
# *Note the count is 53 which indicates there are either duplicates or additional data that may/may not be relevant.*

# %%
sat_19[sat_19['State'].isin(["Puerto Rico","Virgin Islands"])]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                  —   483   462    944
# 47  Virgin Islands                  —   490   445    935

# %%
#Here I am dropping Puerto Rico and Virgin Islands as I want to focus just on 50 states + D.C.

sat_19.drop([39,47],0,inplace=True)

# %%
sat_19['Participation Rate'] = data_clean_func(list(sat_19['Participation Rate']))

# %%
sat_19.rename(columns = {'Participation Rate':'Participation'}, inplace=True)
sat_19.columns = sat_19.columns.str.lower()
sat_19.head()
# Out:
#         state  participation  ebrw  math  total
# 0     Alabama           0.07   583   560   1143
# 1      Alaska           0.41   556   541   1097
# 2     Arizona           0.31   569   565   1134
# 3    Arkansas           0.06   582   559   1141
# 4  California           0.63   534   531   1065

# %%
sat_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   ebrw           51 non-null     int64
#  3   math           51 non-null     int64
#  4   total          51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.4+ KB

# %%
act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# Here I am dropping the first line 'National'

act_17.drop(0,0,inplace = True)

# %%
act_17.describe()
# Out:
#          English       Math    Reading    Science
# count  51.000000  51.000000  51.000000  51.000000
# mean   20.931373  21.182353  22.013725  21.041176
# std     2.353677   1.981989   2.067271   3.182463
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.450000  19.900000
# 50%    20.700000  20.900000  21.800000  21.300000
# 75%    23.300000  23.100000  24.150000  22.750000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   English        51 non-null     float64
#  3   Math           51 non-null     float64
#  4   Reading        51 non-null     float64
#  5   Science        51 non-null     float64
#  6   Composite      51 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.2+ KB

# %% [markdown]
# *Composite dtype is object which indicates there may be a data entry error.*

# %%
act_17.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
# Replacing the value 20.2x to be just 20.2 for Wyoming mean Composite score and changing the dtype to float.

act_17.loc[act_17['State']=='Wyoming','Composite'] = 20.2
act_17['Composite'] = act_17['Composite'].astype(float)

act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   English        51 non-null     float64
#  3   Math           51 non-null     float64
#  4   Reading        51 non-null     float64
#  5   Science        51 non-null     float64
#  6   Composite      51 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 3.2+ KB

# %%
act_17['Participation'] = data_clean_func(list(act_17['Participation']))
act_17.columns = act_17.columns.str.lower()

act_17.head()
# Out:
#         state  participation  english  math  reading  science  composite
# 1     Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2      Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3     Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4    Arkansas           1.00     18.9  19.0     19.7     19.5       19.4
# 5  California           0.31     22.5  22.7     23.1     22.2       22.8

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   english        51 non-null     float64
#  3   math           51 non-null     float64
#  4   reading        51 non-null     float64
#  5   science        51 non-null     float64
#  6   composite      51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.2+ KB

# %%
act_18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act_18.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %% [markdown]
# *Note the count is 52*

# %%
act_18[act_18['State'] == 'Maine']
# Out:
#     State Participation  Composite
# 19  Maine            7%       24.0
# 20  Maine            7%       24.0

# %%
# Dropping Maine since it has a duplicate line

act_18.drop(19,0,inplace=True)

# %%
act_18[act_18['State'] == 'District of columbia']
# Out:
#                   State Participation  Composite
# 8  District of columbia           32%       23.6

# %%
# Correcting District of columbia to District of Columbia for consistency in State name convention

act_18.loc[act_18['State']=='District of columbia',"State"] = 'District of Columbia'

# %%
act_18['Participation'] = data_clean_func(list(act_18['Participation']))
act_18.columns = act_18.columns.str.lower()

act_18.head()
# Out:
#         state  participation  composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
act_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   composite      51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB

# %%
act_19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# *Note the count is 52.*

# %%
act_19.tail()
# Out:
#             State Participation  Composite
# 47     Washington           24%       22.1
# 48  West Virginia           49%       20.8
# 49      Wisconsin          100%       20.3
# 50        Wyoming          100%       19.8
# 51       National           52%       20.7

# %%
# Dropping 'National'

act_19.drop(51,0,inplace=True)

# %%
act_19['Participation'] = data_clean_func(list(act_19['Participation']))
act_19.columns = act_19.columns.str.lower()

act_19.head()
# Out:
#         state  participation  composite
# 0     Alabama           1.00       18.9
# 1      Alaska           0.38       20.1
# 2     Arizona           0.73       19.0
# 3    Arkansas           1.00       19.3
# 4  California           0.23       22.6

# %%
act_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   composite      51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB

# %%
us_income.head()
# Out:
#         State Median income Standard error
# 0     Alabama        53,363          1,434
# 1      Alaska        76,570          3,315
# 2     Arizona        65,450          1,836
# 3    Arkansas        52,370          1,396
# 4  California        74,305          1,108

# %%
# Dropping standard error column

us_income.drop(columns=['Standard error'], inplace=True)

# %%
# Taking the comma out within median income and converting to float

median_income = []
for income in us_income['Median income']:
    median_income.append(float(income.replace(',',"")))
    
us_income['Median income'] = median_income

# %%
us_income.rename(columns = {'State':'state', 'Median income':'med_income'},inplace=True)

# %%
us_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   state       51 non-null     object
#  1   med_income  51 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 944.0+ bytes

# %%
# Consolidating SAT data into one dataframe 'sat_total'
sat_17_total = sat_17.loc[:,['state','participation','total']]
sat_17_total.rename(columns = {'participation' : '2017_sat_part','total':'2017_sat_total'},inplace=True)

sat_18_total = sat_18.loc[:,['state','participation','total']]
sat_18_total.rename(columns = {'participation' : '2018_sat_part','total':'2018_sat_total'},inplace=True)

sat_19_total = sat_19.loc[:,['state','participation','total']]
sat_19_total.rename(columns = {'participation' : '2019_sat_part','total':'2019_sat_total'},inplace=True)

sat_17_18_total = pd.merge(sat_17_total,sat_18_total)
sat_total = pd.merge(sat_17_18_total,sat_19_total)

# Consolidating ACT data into one dataframe 'act_total'
act_17_total = act_17.loc[:,['state','participation','composite']]
act_17_total.rename(columns = {'participation' : '2017_act_part','composite':'2017_act_comp'},inplace=True)

act_18_total = act_18.loc[:,['state','participation','composite']]
act_18_total.rename(columns = {'participation' : '2018_act_part','composite':'2018_act_comp'},inplace=True)

act_19_total = act_19.loc[:,['state','participation','composite']]
act_19_total.rename(columns = {'participation' : '2019_act_part','composite':'2019_act_comp'},inplace=True)

act_17_18_total = pd.merge(act_17_total,act_18_total)
act_total = pd.merge(act_17_18_total,act_19_total)

# Consolidating SAT and ACT data into one dataframe 'sat_act_total'
sat_act_total = pd.merge(sat_total,act_total)

# Finally, merging 'sat_act_total' and 'us_income' to create one final dataframe
final_data = pd.merge(sat_act_total,us_income)

# %%
final_data.head()
# Out:
#         state  2017_sat_part  2017_sat_total  2018_sat_part  2018_sat_total  \
# 0     Alabama           0.05            1165           0.06            1166
# 1      Alaska           0.38            1080           0.43            1106
# 2     Arizona           0.30            1116           0.29            1149
# 3    Arkansas           0.03            1208           0.05            1169
# 4  California           0.53            1055           0.60            1076
#
#    2019_sat_part  2019_sat_total  2017_act_part  2017_act_comp  2018_act_part  \
# 0           0.07            1143           1.00           19.2           1.00
# 1           0.41            1097           0.65           19.8           0.33
# 2           0.31            1134           0.62           19.7           0.66
# 3           0.06            1141           1.00           19.4           1.00
# 4           0.63            1065           0.31           22.8           0.27
#
# ...

# %% [markdown]
# ### Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|object|final_datal|U.S State (including District of Columbia)|
# |**sat_part**|float|final_data|SAT Participation Rate by State|
# |**sat_total**|int|final_data|Average SAT Total Score by State|
# |**act_part**|float|final_data|ACT Participation Rate by State|
# |**act_comp**|float|final_data|Average ACT Composite Score by State|
# |**med_income**|float|final_data|U.S. Median Household Income by State (3-Year Moving Average Between (2017-2019)|

# %% [markdown]
# ## Exploratory Data Analysis

# %%
final_data.head()
# Out:
#         state  2017_sat_part  2017_sat_total  2018_sat_part  2018_sat_total  \
# 0     Alabama           0.05            1165           0.06            1166
# 1      Alaska           0.38            1080           0.43            1106
# 2     Arizona           0.30            1116           0.29            1149
# 3    Arkansas           0.03            1208           0.05            1169
# 4  California           0.53            1055           0.60            1076
#
#    2019_sat_part  2019_sat_total  2017_act_part  2017_act_comp  2018_act_part  \
# 0           0.07            1143           1.00           19.2           1.00
# 1           0.41            1097           0.65           19.8           0.33
# 2           0.31            1134           0.62           19.7           0.66
# 3           0.06            1141           1.00           19.4           1.00
# 4           0.63            1065           0.31           22.8           0.27
#
# ...

# %%
final_data.describe().T
# Out:
#                 count          mean           std       min        25%  \
# 2017_sat_part    51.0      0.398039      0.352766      0.02      0.040
# 2017_sat_total   51.0   1126.098039     92.494812    950.00   1055.500
# 2018_sat_part    51.0      0.457451      0.373143      0.02      0.045
# 2018_sat_total   51.0   1120.019608     94.155083    977.00   1057.500
# 2019_sat_part    51.0      0.490588      0.387476      0.02      0.055
# 2019_sat_total   51.0   1113.078431     97.197910    943.00   1038.000
# 2017_act_part    51.0      0.652549      0.321408      0.08      0.310
# 2017_act_comp    51.0     21.519608      2.020695     17.80     19.800
# 2018_act_part    51.0      0.617255      0.340371      0.07      0.285
# 2018_act_comp    51.0     21.496078      2.111583     17.70     19.950
# 2019_act_part    51.0      0.586667      0.345159      0.06      0.245
# 2019_act_comp    51.0     21.464706      2.194523     17.90     19.800
# ...

# %% [markdown]
# From the summary statistics above, we can make some high level/general observations before we dive further into the data. For instance, ACT participation rates seem to be higher than SAT participation rates. However, it's interesting to note SAT participation rate is on the rise whereas ACT participation rate seems to be on the delicine. In terms of test scores, there isn't much voliatility year over year for both SAT and ACT. If we take a look at the mean and median scores for both ACT and SAT, they do not vary widly year over year, which is what we would expect to see since these tests are designed to test competencies in certain areas over a large population of students each year. Furthermore, the mean and median for the median income are fairly close to each other which may suggest a symmetrical distribution. Visually, we should expect to see a curve that closely represents a normal distribution.

# %%
# Applying the calc_std function that I wrote above to all numeric columns.

numeric_columns = list(final_data.columns)
numeric_columns.remove('state') # Dropping state since dtype is object.
numeric_columns

sd = {column:calc_std(final_data[column]) for column in numeric_columns}

sd
# Out:
# {'2017_sat_part': 0.3492907076664507,
#  '2017_sat_total': 91.58351056778743,
#  '2018_sat_part': 0.3694661922353942,
#  '2018_sat_total': 93.22742384464433,
#  '2019_sat_part': 0.3836584048685726,
#  '2019_sat_total': 96.24027185617864,
#  '2017_act_part': 0.3182417575123181,
#  '2017_act_comp': 2.000786081581989,
#  '2018_act_part': 0.33701735820410317,
#  '2018_act_comp': 2.090779082141178,
#  '2019_act_part': 0.3417582373703047,
#  '2019_act_comp': 2.172901153595978,
#  'med_income': 10478.568292738764}

# %% [markdown]
# *By default, the standard deviations are normalized by N-1 in pandas which explains the difference.*
# Source: https://www.geeksforgeeks.org/python-pandas-dataframe-std/

# %% [markdown]
# #### SAT Mean Scores, Participation Rates, and Median Income by State (Top & Bottom 10 sorted by Median Income)

# %%
final_data.groupby('state')[['med_income','2017_sat_total', '2018_sat_total', '2019_sat_total','2017_sat_part','2018_sat_part','2019_sat_part']].sum().sort_values('med_income', ascending=False).head(10)
# Out:
#                       med_income  2017_sat_total  2018_sat_total  \
# state
# Maryland                 89658.0            1060            1080
# District of Columbia     88396.0             950             977
# Massachusetts            85044.0            1107            1125
# New Hampshire            82866.0            1052            1063
# Hawaii                   82108.0            1085            1010
# Connecticut              79639.0            1041            1053
# Washington               79412.0            1075            1081
# New Jersey               79182.0            1056            1094
# Utah                     78591.0            1238            1010
# Virginia                 77904.0            1102            1117
#
#                       2019_sat_total  2017_sat_part  2018_sat_part  \
# state
# Maryland                        1058           0.69           0.76
# District of Columbia             975           1.00           0.92
# ...

# %%
final_data.groupby('state')[['med_income','2017_sat_total', '2018_sat_total', '2019_sat_total','2017_sat_part','2018_sat_part','2019_sat_part']].sum().sort_values('med_income', ascending=False).tail(10)
# Out:
#                 med_income  2017_sat_total  2018_sat_total  2019_sat_total  \
# state
# Florida            56456.0            1017            1099             999
# Oklahoma           56309.0            1047            1062             963
# North Carolina     55723.0            1081            1098            1100
# Kentucky           54337.0            1247            1248            1232
# Alabama            53363.0            1165            1166            1143
# Arkansas           52370.0            1208            1169            1141
# West Virginia      51390.0            1086             999             943
# New Mexico         49943.0            1138            1093            1073
# Louisiana          49340.0            1198            1210            1200
# Mississippi        44494.0            1242            1236            1237
#
#                 2017_sat_part  2018_sat_part  2019_sat_part
# state
# Florida                  0.83           0.56           1.00
# ...

# %% [markdown]
# When comparing SAT mean scores and participation rates of all the states sorted by the median income, there appears to be an interesting dynamic at play, especially between SAT mean scores and participation rates (except for a few outliers in both cases). For example, SAT mean scores for the top 10 median income states are lower than average whereas the mean SAT scores for the bottom 10 states are above average. However, the converse is true for SAT participation rates. Many top 10 states have higher than average SAT participation rates whereas many bottom 10 have very small participation rates. To account for this "low participation, high score" effect, takeaway here is to account for this noise. One reasonable way to do this would be to narrow down the data by where participation >= 0.5.

# %% [markdown]
# #### ACT Mean Scores, Participation Rates, and Median Income by State (Top & Bottom 10 sorted by Median Income)

# %%
final_data.groupby('state')[['med_income','2017_act_comp', '2018_act_comp', '2019_act_comp','2017_act_part','2018_act_part','2019_act_part']].sum().sort_values('med_income', ascending=False).head(10)
# Out:
#                       med_income  2017_act_comp  2018_act_comp  2019_act_comp  \
# state
# Maryland                 89658.0           23.6           22.5           22.3
# District of Columbia     88396.0           24.2           23.6           23.5
# Massachusetts            85044.0           25.4           25.5           25.5
# New Hampshire            82866.0           25.5           25.1           25.0
# Hawaii                   82108.0           19.0           18.9           19.0
# Connecticut              79639.0           25.2           25.6           25.5
# Washington               79412.0           21.9           22.2           22.1
# New Jersey               79182.0           23.9           23.7           24.2
# Utah                     78591.0           20.3           20.4           20.3
# Virginia                 77904.0           23.8           23.9           24.0
#
#                       2017_act_part  2018_act_part  2019_act_part
# state
# ...

# %%
final_data.groupby('state')[['med_income','2017_act_comp', '2018_act_comp', '2019_act_comp','2017_act_part','2018_act_part','2019_act_part']].sum().sort_values('med_income', ascending=False).tail(10)
# Out:
#                 med_income  2017_act_comp  2018_act_comp  2019_act_comp  \
# state
# Florida            56456.0           19.8           19.9           20.1
# Oklahoma           56309.0           19.4           19.3           18.9
# North Carolina     55723.0           19.1           19.1           19.0
# Kentucky           54337.0           20.0           20.2           19.8
# Alabama            53363.0           19.2           19.1           18.9
# Arkansas           52370.0           19.4           19.4           19.3
# West Virginia      51390.0           20.4           20.3           20.8
# New Mexico         49943.0           19.7           19.4           19.3
# Louisiana          49340.0           19.5           19.2           18.8
# Mississippi        44494.0           18.6           18.6           18.4
#
#                 2017_act_part  2018_act_part  2019_act_part
# state
# Florida                  0.73           0.66           0.54
# ...

# %% [markdown]
# When comparing ACT mean composite scores and participation rates for the top 10 and bottom 10 states, there seems to be a positive correlation between median income and mean ACT composite scores. For example, top 10 states have above average mean ACT composite scores whereas bottom 10 states have lower than average ACT composite scores. ACT participation rates in the bottom 10 states are well above average and below the average in the top 10. Similar to SAT, this dynamic may cause some unncessary noise when comparing relationship to median income. Same as above, it may be reasonable to narrow down the states to where participation rate >= 0.5.

# %% [markdown]
# #### SAT Mean Scores, Participation Rates, and Median Income by State (Top & Bottom 10 sorted by 2019 Mean SAT Score)

# %%
final_data.groupby('state')[['med_income','2017_sat_total', '2018_sat_total', '2019_sat_total','2017_sat_part','2018_sat_part','2019_sat_part']].sum().sort_values('2019_sat_total', ascending=False).head(10)
# Out:
#               med_income  2017_sat_total  2018_sat_total  2019_sat_total  \
# state
# Minnesota        75841.0            1295            1298            1284
# Wisconsin        65775.0            1291            1294            1283
# South Dakota     61384.0            1216            1240            1268
# North Dakota     66830.0            1256            1283            1263
# Nebraska         68004.0            1253            1252            1260
# Iowa             67403.0            1275            1265            1244
# Kansas           65864.0            1260            1265            1241
# Wyoming          63633.0            1230            1257            1238
# Mississippi      44494.0            1242            1236            1237
# Missouri         60799.0            1271            1262            1236
#
#               2017_sat_part  2018_sat_part  2019_sat_part
# state
# Minnesota              0.03           0.04           0.04
# ...

# %%
final_data.groupby('state')[['med_income','2017_sat_total', '2018_sat_total', '2019_sat_total','2017_sat_part','2018_sat_part','2019_sat_part']].sum().sort_values('2019_sat_total', ascending=False).tail(10)
# Out:
#                       med_income  2017_sat_total  2018_sat_total  \
# state
# Maine                    60626.0            1012            1013
# Illinois                 71539.0            1115            1019
# Michigan                 61497.0            1005            1011
# Florida                  56456.0            1017            1099
# Rhode Island             67251.0            1062            1018
# Idaho                    62611.0            1005            1001
# Delaware                 69378.0             996             998
# District of Columbia     88396.0             950             977
# Oklahoma                 56309.0            1047            1062
# West Virginia            51390.0            1086             999
#
#                       2019_sat_total  2017_sat_part  2018_sat_part  \
# state
# Maine                           1013           0.95           0.99
# Illinois                        1013           0.09           0.99
# ...

# %% [markdown]
# When we sort the data by top average SAT score, we can see the "low participation, high score" impact more clearly.(As a side note, I used 2019 SAT score to sort since there isn't much volitality in average SAT score year over). Looking at the SAT participation rates for the top 10 states, many fall under the <5% range. In the bottom 10, particular states like Illinois, Oklahoma, and West Virginia look unusual. 2017 Illinois SAT participation rate is at 9% and it increases to 99% and 100% in 2018 and 2019 respectively *(See further down below for detail on Illinois)*. States like Oklahoma and West Virginia are also unusual to have low average SAT scores with low participation rates in 2017 and 2018.

# %% [markdown]
# #### ACT Mean Scores, Participation Rates, and Median Income by State (Top & Bottom 10 sorted by 2019 Average ACT Scores)

# %%
final_data.groupby('state')[['med_income','2017_act_comp', '2018_act_comp', '2019_act_comp','2017_act_part','2018_act_part','2019_act_part']].sum().sort_values('2019_act_comp', ascending=False).head(10)
# Out:
#                med_income  2017_act_comp  2018_act_comp  2019_act_comp  \
# state
# Massachusetts     85044.0           25.4           25.5           25.5
# Connecticut       79639.0           25.2           25.6           25.5
# New Hampshire     82866.0           25.5           25.1           25.0
# Rhode Island      67251.0           24.0           24.2           24.7
# New York          68178.0           24.2           24.5           24.5
# Michigan          61497.0           24.1           24.2           24.4
# Maine             60626.0           24.3           24.0           24.3
# Illinois          71539.0           21.4           23.9           24.3
# New Jersey        79182.0           23.9           23.7           24.2
# Vermont           70685.0           23.6           24.1           24.1
#
#                2017_act_part  2018_act_part  2019_act_part
# state
# Massachusetts           0.29           0.25           0.21
# ...

# %%
final_data.groupby('state')[['med_income','2017_act_comp', '2018_act_comp', '2019_act_comp','2017_act_part','2018_act_part','2019_act_part']].sum().sort_values('2019_act_comp', ascending=False).tail(10)
# Out:
#                 med_income  2017_act_comp  2018_act_comp  2019_act_comp  \
# state
# Arkansas           52370.0           19.4           19.4           19.3
# North Carolina     55723.0           19.1           19.1           19.0
# Hawaii             82108.0           19.0           18.9           19.0
# Arizona            65450.0           19.7           19.2           19.0
# Oklahoma           56309.0           19.4           19.3           18.9
# Alabama            53363.0           19.2           19.1           18.9
# South Carolina     59130.0           18.7           18.3           18.8
# Louisiana          49340.0           19.5           19.2           18.8
# Mississippi        44494.0           18.6           18.6           18.4
# Nevada             64808.0           17.8           17.7           17.9
#
#                 2017_act_part  2018_act_part  2019_act_part
# state
# Arkansas                 1.00           1.00           1.00
# ...

# %% [markdown]
# When we sort the data by top average ACT score (using 2019 ACT average score), the positive correlation between the average score and median income is definitely more apparent than with SAT.

# %%
# Creating SAT and ACT Participation Rate change year over year ((2017 vs 2018, 2018 vs 2019))

final_data['18v17_sat_part'] = final_data['2018_sat_part']-final_data['2017_sat_part']
final_data['19v18_sat_part'] = final_data['2019_sat_part']-final_data['2018_sat_part']
final_data['18v17_act_part'] = final_data['2018_act_part']-final_data['2017_act_part']
final_data['19v18_act_part'] = final_data['2019_act_part']-final_data['2018_act_part']

# %%
final_data.groupby('state')[['2017_sat_part', '2018_sat_part','18v17_sat_part']].sum().sort_values('18v17_sat_part', ascending=False).head()
# Out:
#                2017_sat_part  2018_sat_part  18v17_sat_part
# state
# Illinois                0.09           0.99            0.90
# Colorado                0.11           1.00            0.89
# Rhode Island            0.71           0.97            0.26
# West Virginia           0.14           0.28            0.14
# New Jersey              0.70           0.82            0.12

# %%
final_data.groupby('state')[['2017_sat_part', '2018_sat_part','18v17_sat_part']].sum().sort_values('18v17_sat_part', ascending=False).tail()
# Out:
#                       2017_sat_part  2018_sat_part  18v17_sat_part
# state
# Wyoming                        0.03           0.03            0.00
# Arizona                        0.30           0.29           -0.01
# Nevada                         0.26           0.23           -0.03
# District of Columbia           1.00           0.92           -0.08
# Florida                        0.83           0.56           -0.27

# %%
final_data.groupby('state')[['2018_sat_part', '2019_sat_part','19v18_sat_part']].sum().sort_values('19v18_sat_part', ascending=False).head()
# Out:
#                 2018_sat_part  2019_sat_part  19v18_sat_part
# state
# West Virginia            0.28           0.99            0.71
# Florida                  0.56           1.00            0.44
# Oklahoma                 0.08           0.22            0.14
# South Carolina           0.55           0.68            0.13
# Maryland                 0.76           0.82            0.06

# %%
final_data.groupby('state')[['2018_sat_part', '2019_sat_part','19v18_sat_part']].sum().sort_values('19v18_sat_part', ascending=False).tail()
# Out:
#                 2018_sat_part  2019_sat_part  19v18_sat_part
# state
# Montana                  0.10           0.09           -0.01
# North Carolina           0.52           0.51           -0.01
# Alaska                   0.43           0.41           -0.02
# Hawaii                   0.56           0.54           -0.02
# Nevada                   0.23           0.20           -0.03

# %% [markdown]
# Examining the SAT Particpation Rate changes year over year, we can see some dramatic changes in certain states. Illinois went from 9% SAT participation rate in 2017 to 99% and 90% in 2018 and 2019 respectively. Upon further research, I discovered that [College Board (administer of SAT) won a three-year bid in Illinois and replaced ACT.](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html) Similar to Illinois, [Colorado also mandated SAT in 2017](https://www.testive.com/colorado-sat-change-2017/)

# %%
final_data.groupby('state')[['2017_act_part', '2018_act_part','18v17_act_part']].sum().sort_values('18v17_act_part', ascending=False).head()
# Out:
#           2017_act_part  2018_act_part  18v17_act_part
# state
# Ohio               0.75           1.00            0.25
# Nebraska           0.84           1.00            0.16
# Arizona            0.62           0.66            0.04
# Maryland           0.28           0.31            0.03
# Oregon             0.40           0.42            0.02

# %%
final_data.groupby('state')[['2017_act_part', '2018_act_part','18v17_act_part']].sum().sort_values('18v17_act_part', ascending=False).tail()
# Out:
#           2017_act_part  2018_act_part  18v17_act_part
# state
# Florida            0.73           0.66           -0.07
# Michigan           0.29           0.22           -0.07
# Alaska             0.65           0.33           -0.32
# Illinois           0.93           0.43           -0.50
# Colorado           1.00           0.30           -0.70

# %%
final_data.groupby('state')[['2018_act_part', '2019_act_part','19v18_act_part']].sum().sort_values('19v18_act_part', ascending=False).head()
# Out:
#              2018_act_part  2019_act_part  19v18_act_part
# state
# Arizona               0.66           0.73            0.07
# Alaska                0.33           0.38            0.05
# Kansas                0.71           0.72            0.01
# Ohio                  1.00           1.00            0.00
# Mississippi           1.00           1.00            0.00

# %%
final_data.groupby('state')[['2018_act_part', '2019_act_part','19v18_act_part']].sum().sort_values('19v18_act_part', ascending=False).tail()
# Out:
#                 2018_act_part  2019_act_part  19v18_act_part
# state
# Hawaii                   0.89           0.80           -0.09
# Florida                  0.66           0.54           -0.12
# West Virginia            0.65           0.49           -0.16
# Missouri                 1.00           0.82           -0.18
# South Carolina           1.00           0.78           -0.22

# %% [markdown]
# Examining the ACT Participation Rate changes year over year, there doesn't appear to be any significant swings year over year. We do see the offsetting impact of states like Illinois and Colorado fully switching over to SAT.

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(15,8))
plt.title('SAT/ACT Correlation Heatmap',fontsize=20)
sns.heatmap(final_data.corr(), cmap='RdBu',vmin=-1, vmax=1, annot=True, annot_kws={'fontsize':13}, linewidth=0.5);
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15);

# %%
plt.figure(figsize=(15,8))
plt.title('Median Income Correlation Heatmap',fontsize=20)
sns.heatmap(final_data.corr()[['med_income']], cmap='RdBu',vmin=-1, vmax=1, annot=True, annot_kws={'fontsize':13}, linewidth=0.5);
plt.xticks(fontsize=15)
plt.yticks(fontsize=15);

# %% [markdown]
# Visual examination of correlation between median income and SAT/ACT test scores aligns with initial impressions. Note that SAT scores are shaded in light pink which indicate there isn't a strong relationship. However, with ACT scores, they are shaded in mid-blue which indicates that there is a positive correlation between the two variables.

# %%
plt.figure(figsize=(10,8))
sns.set(font_scale=1.5)
sns.histplot(final_data['med_income'], bins=10, alpha=0.6)
plt.axvline(np.mean(final_data['med_income']), color='r', lw=5)
plt.axvline(np.median(final_data['med_income']), color='g', lw=5, linestyle ='--')
plt.ylabel(ylabel="")
plt.xlabel(xlabel='Median Household Income($)')
plt.title('Median Income Distribution')
plt.legend(labels = ['mean','median']);

# %% [markdown]
# Looking at the distribution of median income, we see that the mean and median are closely positioned which suggests the distribution is symmetrical. In fact, the distribution of the median income closely mimics a normal distribution.  As a contextual background, the US Census Bureau provides a detailed explanation of methodology used for their estimation of median incomes. In essence, the Census Bureau uses the linear interpoliation methodology to estimate all medians. One key assumption with linear interpolation is that the density of population within an income interval stays constant. Specific details regarding the methodology, standard error, and confidence interval can be found directly in their [2020 Annual Social and Economic Suppplement](https://www2.census.gov/programs-surveys/cps/techdocs/cpsmar20.pdf). For the purposes of this particular analysis, it suffices to say the median income estimation provided by the Census Bureau looks reasonably well constructed.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2017_sat_part'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='Participation Rate')
plt.title('2017 SAT')

plt.subplot(1,3,2)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2018_sat_part'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='Participation Rate')
plt.title('2018 SAT')

plt.subplot(1,3,3)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2019_sat_part'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='Participation Rate')
plt.title('2019 SAT');

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2017_act_part'], bins=10)
plt.ylabel(ylabel="");
plt.xlabel(xlabel='Participation Rate')
plt.title('2017 ACT')

plt.subplot(1,3,2)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2018_act_part'], bins=10)
plt.ylabel(ylabel="");
plt.xlabel(xlabel='Participation Rate')
plt.title('2018 ACT')


plt.subplot(1,3,3)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2019_act_part'], bins=10)
plt.ylabel(ylabel="");
plt.xlabel(xlabel='Participation Rate')
plt.title('2019 ACT');

# %% [markdown]
# For both SAT and ACT, their participation rates have not drastically changed year over year. Interesting observation here is that the SAT participation distribution shows a large number of states with participation rate less than 10%. On the other hand, ACT participation distribution is showing a strong presence of states with participation rate >90%. It appears that in certain states,  ACT is definitely preferred over SAT.
#
# For SAT, a large presence of states with low participation rate may cause some data noise when limiting the states based on participation rate >=0.5 criteria. Same applies for ACT as well but given many states fall in the >90% scale, I expect to see a stronger correlation.

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2017_sat_total'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='SAT Score')
plt.title('2017 SAT')

plt.subplot(1,3,2)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2018_sat_total'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='SAT Score')
plt.title('2018 SAT')


plt.subplot(1,3,3)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2019_sat_total'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='SAT Score')
plt.title('2019 SAT');

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2017_act_comp'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='ACT Score')
plt.title('2017 ACT')

plt.subplot(1,3,2)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2018_act_comp'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='ACT Score')
plt.title('2018 ACT')


plt.subplot(1,3,3)
sns.set(font_scale=1.5)
sns.set_style('white')
sns.histplot(final_data['2019_act_comp'], bins=10)
plt.ylabel(ylabel="")
plt.xlabel(xlabel='ACT Score')
plt.title('2019 ACT');

# %% [markdown]
# For both SAT and ACT, their test score distribution is exhibiting bimodal-like behavior, especially the dip in the middle of the distribution graph. The bimodal behavior jives with the "low participation, high score" impact that we discussed in the data exploratory analysis portion. The second peak in both SAT and ACT scores could be caused by the fact that we have a number of states with low participation rates in respective tests, but higher than average scores.
#
# Consequently, placing a participation rate >=0.5 when analyzing the correlation in respect to median income should help with reducing noise caused by the strong SAT/ACT preference in a large number of states and as well as by "low participation, high mean score" effect.

# %%
sat_total_bp = final_data.loc[:,['2017_sat_total','2018_sat_total','2019_sat_total']]
sat_total_bp = sat_total_bp.rename(columns = {'2017_sat_total':'2017 SAT','2018_sat_total':'2018 SAT', '2019_sat_total':'2019 SAT'})

act_comp_bp = final_data.loc[:,['2017_act_comp','2018_act_comp','2019_act_comp']]
act_comp_bp = act_comp_bp.rename(columns = {'2017_act_comp':'2017 ACT','2018_act_comp':'2018 ACT', '2019_act_comp':'2019 ACT'})
                       
plt.figure(figsize=(20,5))
                       
plt.subplot(1,2,1)
sns.boxplot(orient='h', data=sat_total_bp);
plt.xlabel(xlabel='SAT Scores')
plt.title('SAT Score Boxplot')

plt.subplot(1,2,2)
sns.boxplot(orient='h', data=act_comp_bp);
plt.xlabel(xlabel='ACT Scores')
plt.title('ACT Score Boxplot');

# %% [markdown]
# As noted during the data exploration portion of the analysis, we can visually see that for both SAT and ACT, there is little volitiatlity in their test scores year over year. In both cases, there is minimum movement of the median and majoirty of the scores fall in the upper half of the boxplot. We also do not have any outliers in our test score for both SAT and ACT.

# %%
sat_part_bp = final_data.loc[:,['2017_sat_part','2018_sat_part','2019_sat_part']]
sat_part_bp = sat_part_bp.rename(columns = {'2017_sat_part':'2017 SAT','2018_sat_part':'2018 SAT', '2019_sat_part':'2019 SAT'})

act_part_bp = final_data.loc[:,['2017_act_part','2018_act_part','2019_act_part']]
act_part_bp = act_part_bp.rename(columns = {'2017_act_part':'2017 ACT','2018_act_part':'2018 ACT', '2019_act_part':'2019 ACT'})
                       
plt.figure(figsize=(20,5))
                       
plt.subplot(1,2,1)
sns.boxplot(orient='h', data=sat_part_bp);
plt.xlabel(xlabel='SAT Participation Rates')
plt.title('SAT Participation Boxplot')

plt.subplot(1,2,2)
sns.boxplot(orient='h', data=act_part_bp);
plt.xlabel(xlabel='ACT Participation Rate')
plt.title('ACT Particiatpion  Boxplot');

# %% [markdown]
# While the boxplots of average SAT and ACT scores appear and behave the same, the boxplots for SAT and ACT participation rates behave in opposite manner. For SAT, participation rates are concentrated in the 25-50th percentile range whereas pariticpation rates for ACT are concentrated above the median line. Again this observation is serving as another evidence of strong preference of ACT over SAT in many of the states. We can also see that the center of the participation rate distribution for ACT is higher than SAT distribution.
#
# Given the visual evidence, I believe the correlation between mean ACT composite scores and median income is a better reflection of dynamic relatioinship that may exist between the two variables. While analysis in respect to SAT may still provide some insight as a comparison point, ACT should be the focal point when deriving any conclusions about the relationship between student performance and median income.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
sns.set(font_scale=1.5)
sns.regplot(x=final_data['2017_sat_total'],y=final_data['2017_sat_part'], ci=95, fit_reg=False)
plt.xlabel('SAT Scores')
plt.ylabel('Participation')

sns.regplot(x=final_data['2018_sat_total'],y=final_data['2018_sat_part'], ci=95, fit_reg=False)
plt.xlabel('SAT Scores')
plt.ylabel('Participation')

sns.regplot(x=final_data['2019_sat_total'],y=final_data['2019_sat_part'], ci=95, fit_reg=False)
plt.title('Comparing SAT Scores and Participation')
plt.xlabel('SAT Scores')
plt.ylabel('Participation')

plt.legend(labels = ['2017', '2018', '2019'])


plt.subplot(1,2,2)
sns.set(font_scale=1.5)

sns.regplot(x=final_data['2017_act_comp'],y=final_data['2017_act_part'], ci=95, fit_reg=False)
plt.xlabel('SAT Scores')
plt.ylabel('Participation')

sns.regplot(x=final_data['2018_act_comp'],y=final_data['2018_act_part'], ci=95, fit_reg=False)
plt.xlabel('SAT Scores')
plt.ylabel('Participation')

sns.regplot(x=final_data['2019_act_comp'],y=final_data['2019_act_part'], ci=95, fit_reg=False)
plt.title('Comparing ACT Scores and Participation')
plt.xlabel('ACT Scores')
plt.ylabel('Participation')

plt.legend(labels = ['2017', '2018', '2019']);

# %% [markdown]
# Scatter plots here help to visually understand the "low participation and high score" effect described above. In essence, these clusters in the 4th quadrant (low participation, high score) can skew the statistics of the data.

# %%
# Here I am creating a subset with parameter SAT participation rate >= 0.5

sat_sample = final_data.loc[(final_data['2017_sat_part']>=.5) & (final_data['2018_sat_part']>=.5) & (final_data['2019_sat_part']>=.5),
               ['state','med_income','2017_sat_total','2018_sat_total','2019_sat_total']].sort_values('med_income')

plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
sns.set(font_scale=1.5)
sns.regplot(x='med_income', y='2017_sat_total', ci=95,data=sat_sample)
plt.xlabel('Median Income ($)')
plt.ylabel('2017 SAT Score')

sns.regplot(x='med_income', y='2018_sat_total', ci=95,data=sat_sample)
plt.xlabel('Median Income($)')
plt.ylabel('2018 SAT Score')

sns.regplot(x='med_income', y='2019_sat_total', ci=95,data=sat_sample)
plt.title('Comparing SAT scores and median income (participation >= 0.5)')
plt.xlabel('Median Income($)')
plt.ylabel('SAT Score')
plt.legend(labels = ['2017', '2018', '2019'])


# Here I am creating a subset with parameter ACT participation rate >= 0.5
act_sample = final_data.loc[(final_data['2017_act_part']>=.5) & (final_data['2018_act_part']>=.5) & (final_data['2019_act_part']>=.5),
               ['state','med_income','2017_act_comp','2018_act_comp','2019_act_comp']].sort_values('med_income')

plt.subplot(1,2,2)
sns.set(font_scale=1.5)
sns.regplot(x='med_income', y='2017_act_comp', ci=95,data=act_sample)
plt.xlabel('Median Income ($)')
plt.ylabel('2017 ACT Score')

sns.regplot(x='med_income', y='2018_act_comp', ci=95,data=act_sample)
plt.xlabel('Median Income ($)')
plt.ylabel('2018 ACT Score')

sns.regplot(x='med_income', y='2019_act_comp', ci=95,data=act_sample)
plt.title('Comparing ACT scores with median income (participation >=0.5)')
plt.xlabel('Median Income ($)')
plt.ylabel('ACT Score')
plt.legend(labels = ['2017', '2018', '2019']);

# %% [markdown]
# In both cases, we see some meaningful similarities. For instance, in both plots, we see a lot more clusters in the 3rd quadrant (low income, low test score) than in the upper half of the median income scale (except for outliers).This is an indication that as we move up the median income scale, there is somewhat of an upward movement as we move up the median income scale. We can also see the correlation is much stronger in respect to ACT than SAT as we anticipiated above.

# %%
# Exporting the final_data as csv
final_data.to_csv('../data/final_data.csv')

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# **Based on observations made in this analysis, there is a moderately positive correlation between SAT/ACT scores and household median income**. While correlation does not signify causation, it does not exclude out the possiblity that there may be some underlying dynamic force at play that we as socially responsible data scientists should pause and look further into. This is certainly true when we consider the magnitude of what this potentially could mean for many students who come from low income backgrounds. From experience, we know that there is no perfect system. If we look deep enough, hard enough, carefully enough, we can always find and measure the flaws embedded deeply within our systems, own biases, conscience, and attitudes. I believe the same principle should be applied here as well. It could potentially change the way we evaluate and assess students' true potential in the future.
#
# Here are some major takeaways:
#
# 1. There is a moderately positive correlation between SAT/ACT scores and median household income.
#
# 2. There is a negative correlation between SAT/ACT state average scores and their respective participation rates. This can create a lot of noise due to the fact that states with low SAT/ACT participation rates have very high average test scores. Conseqeuntly, it is important to implement some sort of a controlling parameter to account for this "low participation, high score" effect. In this analysis, my controlling parameter was participation rate >=0.50.
#
# 3. Based on SAT and ACT participation distributions, states have strong preference between SAT and ACT. While many states fall under the < 0.5 SAT participation rate cluster, converse is true for ACT in that many states fall above the > .90 scale. The significance of this bimodal-like behavior is that setting the parameter participation rate >=0.5 cuts more "deeply" into SAT pool than ACT when analyzing correlation in respect to median income. Therefore, in this analysis, correlation that we see between ACT and median income is a slightly better statistical data to lean on.
#
# 3. As socially responsible data scientists, there are a number of other considerations that we should weigh and examine further.
#     1. Decluster the "low participation, high score" effect by obtaining and analyzing more granular set of data. Instead of using a statewide average which can be heavily influnenced by participation rate, use the actual raw data.
#     2. Incorporate a more fitting median income dataset. While the data provided by the US Census Bureau may serve as a good representation of the true population, perhaps it may be more appropriate to work with a subset of that data that may be more relevant such as household median income for families with kids.
#     3. Correlation is not causation. Continue to search and find meaningful relationships, keep testing against measurable variables, and leverage new resources and findings to better fine-tune the regression model.
